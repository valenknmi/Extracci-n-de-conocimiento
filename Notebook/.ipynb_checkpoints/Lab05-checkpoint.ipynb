# %% [markdown]
# # Datos sinteticos
# ## utilizacion de libreria Faker
# Autor: Jose Valentin Contreras Gomez

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-3.0.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\LapOne MX\AppData\Roaming\Python\Python311\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\val\anaconda\envs\Extraccion9AVS\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\LapOne MX\AppData\Roaming\Python\Python311\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\val\anaconda\envs\Extraccion9AVS\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.3-cp311-cp311-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.9 MB 1.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.0/9.9 MB 1.2 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.3/9.9 MB 1.3 MB/s eta 0:00:07
#    ------- -------------------------------- 1.8/9.9 MB 1.4 MB/s eta 0:00:06
#    -------- ------------------------------- 2.1/9.9 MB 1.5 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.6/9.9 MB 1.5 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.9/9.9 MB 1.6 MB/s eta 0:00:05
#    ------------- -------------------------- 3.4/9.9 MB 1.6 MB/s eta 0:00:05
#    --------------- ------------------------ 3.9/9.9 MB 1.7 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.2/9.9 MB 1.7 MB/s eta 0:00:04
#    ------------------- -------------------- 4.7/9.9 MB 1.7 MB/s eta 0:00:04
#    -------------------- ------------------- 5.0/9.9 MB 1.7 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.5/9.9 MB 1.7 MB/s eta 0:00:03
#    ----------------------- ---------------- 5.8/9.9 MB 1.7 MB/s eta 0:00:03
#    ------------------------ --------------- 6.0/9.9 MB 1.7 MB/s eta 0:00:03
#    ------------------------- -------------- 6.3/9.9 MB 1.7 MB/s eta 0:00:03
#    --------------------------- ------------ 6.8/9.9 MB 1.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.1/9.9 MB 1.7 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.3/9.9 MB 1.6 MB/s eta 0:00:02
#    ------------------------------ --------- 7.6/9.9 MB 1.6 MB/s eta 0:00:02
#    ------------------------------- -------- 7.9/9.9 MB 1.6 MB/s eta 0:00:02
#    -------------------------------- ------- 8.1/9.9 MB 1.6 MB/s eta 0:00:02
#    --------------------------------- ------ 8.4/9.9 MB 1.6 MB/s eta 0:00:01
#    --------------------------------- ------ 8.4/9.9 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.7/9.9 MB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.9/9.9 MB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.9/9.9 MB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.9/9.9 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.9 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.9 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.9 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 1.3 MB/s  0:00:08
# Installing collected packages: pandas
# Successfully installed pandas-3.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as mp
import random

# %%
pip install Faker
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting Faker
#   Using cached faker-40.21.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: tzdata in C:\Users\LapOne MX\AppData\Roaming\Python\Python311\site-packages (from Faker) (2026.2)
# Using cached faker-40.21.0-py3-none-any.whl (2.0 MB)
# Installing collected packages: Faker
# Successfully installed Faker-40.21.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script faker.exe is installed in 'C:\Users\LapOne MX\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
from faker import Faker

# %%
fake = Faker("es_MX")

# %%
datos = []
for i in range(100):
    datos.append(
        {
            "id_usuario": i+1,
            "nombre": fake.name(),
            "correo": fake.email(),
            "edad": random.randint(18,65),
            "seguidores": random.randint(50,5000),
            "plataforma": random.choice(["TikTok", "Instagram", "Youtube"])
        }
    )

# %%
dfInfluencer = pd.DataFrame(datos)

# %%
dfInfluencer
# Out:
#     id_usuario                               nombre  \
# 0            1                 Delia Violeta Ávalos
# 1            2                 César Chávez Guillen
# 2            3                Dra. Hermelinda Rivas
# 3            4            Virginia Cristal Quiñones
# 4            5             Gregorio Serafín Carreón
# ..         ...                                  ...
# 95          96  Fernando Gerardo Villanueva Jiménez
# 96          97                 Martín Samuel Rosado
# 97          98           Fernando Contreras Carmona
# 98          99           Maximiliano Holguín Franco
# 99         100                  Emilio Aldo Negrete
#
#                          correo  edad  seguidores plataforma
# 0      oteroernesto@example.org    62        1029    Youtube
# 1          pmontoya@example.com    58        3161     TikTok
# 2       esparzaaldo@example.org    61        2858     TikTok
# 3        adelaleyva@example.org    35        2933  Instagram
# 4          sberrios@example.net    29        4268    Youtube
# ..                          ...   ...         ...        ...
# 95  becerracarolina@example.org    47         735     TikTok
# 96    trevinofelipe@example.com    30        2002  Instagram
# 97      peraltaadan@example.net    49        2178     TikTok
# 98    mateovalencia@example.net    65        3290  Instagram
# 99        adanyanez@example.net    58        3499    Youtube
#
# [100 rows x 6 columns]

# %%
dfInfluencer.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_usuario  100 non-null    int64
#  1   nombre      100 non-null    str
#  2   correo      100 non-null    str
#  3   edad        100 non-null    int64
#  4   seguidores  100 non-null    int64
#  5   plataforma  100 non-null    str
# dtypes: int64(3), str(3)
# memory usage: 4.8 KB

# %%
dfInfluencer.describe()
# Out:
#        id_usuario        edad   seguidores
# count  100.000000  100.000000   100.000000
# mean    50.500000   41.640000  2411.440000
# std     29.011492   13.360215  1264.637284
# min      1.000000   18.000000   327.000000
# 25%     25.750000   30.750000  1338.500000
# 50%     50.500000   39.500000  2264.000000
# 75%     75.250000   55.000000  3372.500000
# max    100.000000   65.000000  4975.000000

# %%
dfInfluencer.describe(include="all")
# Out:
#         id_usuario                nombre                correo        edad  \
# count   100.000000                   100                   100  100.000000
# unique         NaN                   100                    99         NaN
# top            NaN  Delia Violeta Ávalos  sberrios@example.net         NaN
# freq           NaN                     1                     2         NaN
# mean     50.500000                   NaN                   NaN   41.640000
# std      29.011492                   NaN                   NaN   13.360215
# min       1.000000                   NaN                   NaN   18.000000
# 25%      25.750000                   NaN                   NaN   30.750000
# 50%      50.500000                   NaN                   NaN   39.500000
# 75%      75.250000                   NaN                   NaN   55.000000
# max     100.000000                   NaN                   NaN   65.000000
#
#          seguidores plataforma
# count    100.000000        100
# unique          NaN          3
# top             NaN    Youtube
# freq            NaN         37
# mean    2411.440000        NaN
# std     1264.637284        NaN
# min      327.000000        NaN
# 25%     1338.500000        NaN
# 50%     2264.000000        NaN
# 75%     3372.500000        NaN
# max     4975.000000        NaN

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pip install seaborn 
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in C:\Users\LapOne MX\AppData\Roaming\Python\Python311\site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in C:\Users\LapOne MX\AppData\Roaming\Python\Python311\site-packages (from seaborn) (3.0.3)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn)
#   Downloading matplotlib-3.10.9-cp311-cp311-win_amd64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading fonttools-4.63.0-cp311-cp311-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading kiwisolver-1.5.0-cp311-cp311-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in C:\Users\val\anaconda\envs\Extraccion9AVS\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Collecting pillow>=8 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading pillow-12.2.0-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\val\anaconda\envs\Extraccion9AVS\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\LapOne MX\AppData\Roaming\Python\Python311\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\val\anaconda\envs\Extraccion9AVS\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading matplotlib-3.10.9-cp311-cp311-win_amd64.whl (8.2 MB)
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.2 MB 279.5 kB/s eta 0:00:28
#    -- ------------------------------------- 0.5/8.2 MB 279.5 kB/s eta 0:00:28
#    -- ------------------------------------- 0.5/8.2 MB 279.5 kB/s eta 0:00:28
#    -- ------------------------------------- 0.5/8.2 MB 279.5 kB/s eta 0:00:28
#    --- ------------------------------------ 0.8/8.2 MB 310.6 kB/s eta 0:00:24
#    --- ------------------------------------ 0.8/8.2 MB 310.6 kB/s eta 0:00:24
#    --- ------------------------------------ 0.8/8.2 MB 310.6 kB/s eta 0:00:24
#    ----- ---------------------------------- 1.0/8.2 MB 318.5 kB/s eta 0:00:23
#    ----- ---------------------------------- 1.0/8.2 MB 318.5 kB/s eta 0:00:23
#    ----- ---------------------------------- 1.0/8.2 MB 318.5 kB/s eta 0:00:23
#    ----- ---------------------------------- 1.0/8.2 MB 318.5 kB/s eta 0:00:23
#    ------ --------------------------------- 1.3/8.2 MB 321.1 kB/s eta 0:00:22
#    ------ --------------------------------- 1.3/8.2 MB 321.1 kB/s eta 0:00:22
#    ------ --------------------------------- 1.3/8.2 MB 321.1 kB/s eta 0:00:22
#    ------- -------------------------------- 1.6/8.2 MB 331.6 kB/s eta 0:00:21
#    ------- -------------------------------- 1.6/8.2 MB 331.6 kB/s eta 0:00:21
#    ------- -------------------------------- 1.6/8.2 MB 331.6 kB/s eta 0:00:21
#    -------- ------------------------------- 1.8/8.2 MB 335.5 kB/s eta 0:00:19
#    -------- ------------------------------- 1.8/8.2 MB 335.5 kB/s eta 0:00:19
#    -------- ------------------------------- 1.8/8.2 MB 335.5 kB/s eta 0:00:19
#    -------- ------------------------------- 1.8/8.2 MB 335.5 kB/s eta 0:00:19
#    ---------- ----------------------------- 2.1/8.2 MB 339.4 kB/s eta 0:00:18
#    ---------- ----------------------------- 2.1/8.2 MB 339.4 kB/s eta 0:00:18
#    ---------- ----------------------------- 2.1/8.2 MB 339.4 kB/s eta 0:00:18
#    ---------- ----------------------------- 2.1/8.2 MB 339.4 kB/s eta 0:00:18
#    ----------- ---------------------------- 2.4/8.2 MB 336.4 kB/s eta 0:00:18
#    ----------- ---------------------------- 2.4/8.2 MB 336.4 kB/s eta 0:00:18
#    ----------- ---------------------------- 2.4/8.2 MB 336.4 kB/s eta 0:00:18
#    ------------ --------------------------- 2.6/8.2 MB 334.0 kB/s eta 0:00:17
#    ------------ --------------------------- 2.6/8.2 MB 334.0 kB/s eta 0:00:17
#    ------------ --------------------------- 2.6/8.2 MB 334.0 kB/s eta 0:00:17
#    ------------ --------------------------- 2.6/8.2 MB 334.0 kB/s eta 0:00:17
#    -------------- ------------------------- 2.9/8.2 MB 333.5 kB/s eta 0:00:16
#    -------------- ------------------------- 2.9/8.2 MB 333.5 kB/s eta 0:00:16
#    -------------- ------------------------- 2.9/8.2 MB 333.5 kB/s eta 0:00:16
#    -------------- ------------------------- 2.9/8.2 MB 333.5 kB/s eta 0:00:16
#    --------------- ------------------------ 3.1/8.2 MB 327.8 kB/s eta 0:00:16
#    --------------- ------------------------ 3.1/8.2 MB 327.8 kB/s eta 0:00:16
#    --------------- ------------------------ 3.1/8.2 MB 327.8 kB/s eta 0:00:16
#    --------------- ------------------------ 3.1/8.2 MB 327.8 kB/s eta 0:00:16
#    --------------- ------------------------ 3.1/8.2 MB 327.8 kB/s eta 0:00:16
#    --------------- ------------------------ 3.1/8.2 MB 327.8 kB/s eta 0:00:16
#    --------------- ------------------------ 3.1/8.2 MB 327.8 kB/s eta 0:00:16
#    ---------------- ----------------------- 3.4/8.2 MB 305.0 kB/s eta 0:00:16
#    ---------------- ----------------------- 3.4/8.2 MB 305.0 kB/s eta 0:00:16
#    ---------------- ----------------------- 3.4/8.2 MB 305.0 kB/s eta 0:00:16
#    ---------------- ----------------------- 3.4/8.2 MB 305.0 kB/s eta 0:00:16
#    ---------------- ----------------------- 3.4/8.2 MB 305.0 kB/s eta 0:00:16
#    ---------------- ----------------------- 3.4/8.2 MB 305.0 kB/s eta 0:00:16
#    ----------------- ---------------------- 3.7/8.2 MB 294.3 kB/s eta 0:00:16
#    ----------------- ---------------------- 3.7/8.2 MB 294.3 kB/s eta 0:00:16
#    ----------------- ---------------------- 3.7/8.2 MB 294.3 kB/s eta 0:00:16
#    ----------------- ---------------------- 3.7/8.2 MB 294.3 kB/s eta 0:00:16
#    ----------------- ---------------------- 3.7/8.2 MB 294.3 kB/s eta 0:00:16
#    ------------------- -------------------- 3.9/8.2 MB 290.0 kB/s eta 0:00:15
#    ------------------- -------------------- 3.9/8.2 MB 290.0 kB/s eta 0:00:15
#    ------------------- -------------------- 3.9/8.2 MB 290.0 kB/s eta 0:00:15
#    ------------------- -------------------- 3.9/8.2 MB 290.0 kB/s eta 0:00:15
#    -------------------- ------------------- 4.2/8.2 MB 288.6 kB/s eta 0:00:14
#    -------------------- ------------------- 4.2/8.2 MB 288.6 kB/s eta 0:00:14
#    -------------------- ------------------- 4.2/8.2 MB 288.6 kB/s eta 0:00:14
#    -------------------- ------------------- 4.2/8.2 MB 288.6 kB/s eta 0:00:14
#    -------------------- ------------------- 4.2/8.2 MB 288.6 kB/s eta 0:00:14
#    -------------------- ------------------- 4.2/8.2 MB 288.6 kB/s eta 0:00:14
#    --------------------- ------------------ 4.5/8.2 MB 284.6 kB/s eta 0:00:14
#    --------------------- ------------------ 4.5/8.2 MB 284.6 kB/s eta 0:00:14
#    --------------------- ------------------ 4.5/8.2 MB 284.6 kB/s eta 0:00:14
#    --------------------- ------------------ 4.5/8.2 MB 284.6 kB/s eta 0:00:14
#    --------------------- ------------------ 4.5/8.2 MB 284.6 kB/s eta 0:00:14
#    ----------------------- ---------------- 4.7/8.2 MB 281.8 kB/s eta 0:00:13
#    ----------------------- ---------------- 4.7/8.2 MB 281.8 kB/s eta 0:00:13
#    ----------------------- ---------------- 4.7/8.2 MB 281.8 kB/s eta 0:00:13
#    ----------------------- ---------------- 4.7/8.2 MB 281.8 kB/s eta 0:00:13
#    ----------------------- ---------------- 4.7/8.2 MB 281.8 kB/s eta 0:00:13
#    ------------------------ --------------- 5.0/8.2 MB 278.8 kB/s eta 0:00:12
#    ------------------------ --------------- 5.0/8.2 MB 278.8 kB/s eta 0:00:12
#    ------------------------ --------------- 5.0/8.2 MB 278.8 kB/s eta 0:00:12
#    ------------------------ --------------- 5.0/8.2 MB 278.8 kB/s eta 0:00:12
#    ------------------------- -------------- 5.2/8.2 MB 279.9 kB/s eta 0:00:11
#    ------------------------- -------------- 5.2/8.2 MB 279.9 kB/s eta 0:00:11
#    ------------------------- -------------- 5.2/8.2 MB 279.9 kB/s eta 0:00:11
#    ------------------------- -------------- 5.2/8.2 MB 279.9 kB/s eta 0:00:11
#    ------------------------- -------------- 5.2/8.2 MB 279.9 kB/s eta 0:00:11
#    ------------------------- -------------- 5.2/8.2 MB 279.9 kB/s eta 0:00:11
#    -------------------------- ------------- 5.5/8.2 MB 272.8 kB/s eta 0:00:10
#    -------------------------- ------------- 5.5/8.2 MB 272.8 kB/s eta 0:00:10
#    -------------------------- ------------- 5.5/8.2 MB 272.8 kB/s eta 0:00:10
#    -------------------------- ------------- 5.5/8.2 MB 272.8 kB/s eta 0:00:10
#    ---------------------------- ----------- 5.8/8.2 MB 275.7 kB/s eta 0:00:09
#    ---------------------------- ----------- 5.8/8.2 MB 275.7 kB/s eta 0:00:09
#    ---------------------------- ----------- 5.8/8.2 MB 275.7 kB/s eta 0:00:09
#    ----------------------------- ---------- 6.0/8.2 MB 278.4 kB/s eta 0:00:08
#    ----------------------------- ---------- 6.0/8.2 MB 278.4 kB/s eta 0:00:08
#    ----------------------------- ---------- 6.0/8.2 MB 278.4 kB/s eta 0:00:08
#    ----------------------------- ---------- 6.0/8.2 MB 278.4 kB/s eta 0:00:08
#    ------------------------------ --------- 6.3/8.2 MB 281.5 kB/s eta 0:00:07
#    ------------------------------ --------- 6.3/8.2 MB 281.5 kB/s eta 0:00:07
#    ------------------------------ --------- 6.3/8.2 MB 281.5 kB/s eta 0:00:07
#    ------------------------------- -------- 6.6/8.2 MB 284.2 kB/s eta 0:00:06
#    ------------------------------- -------- 6.6/8.2 MB 284.2 kB/s eta 0:00:06
#    ------------------------------- -------- 6.6/8.2 MB 284.2 kB/s eta 0:00:06
#    ------------------------------- -------- 6.6/8.2 MB 284.2 kB/s eta 0:00:06
#    ------------------------------- -------- 6.6/8.2 MB 284.2 kB/s eta 0:00:06
#    --------------------------------- ------ 6.8/8.2 MB 281.3 kB/s eta 0:00:05
#    --------------------------------- ------ 6.8/8.2 MB 281.3 kB/s eta 0:00:05
#    --------------------------------- ------ 6.8/8.2 MB 281.3 kB/s eta 0:00:05
#    --------------------------------- ------ 6.8/8.2 MB 281.3 kB/s eta 0:00:05
#    ---------------------------------- ----- 7.1/8.2 MB 283.6 kB/s eta 0:00:04
#    ---------------------------------- ----- 7.1/8.2 MB 283.6 kB/s eta 0:00:04
#    ---------------------------------- ----- 7.1/8.2 MB 283.6 kB/s eta 0:00:04
#    ----------------------------------- ---- 7.3/8.2 MB 286.5 kB/s eta 0:00:04
#    ----------------------------------- ---- 7.3/8.2 MB 286.5 kB/s eta 0:00:04
#    ----------------------------------- ---- 7.3/8.2 MB 286.5 kB/s eta 0:00:04
#    ------------------------------------- -- 7.6/8.2 MB 289.4 kB/s eta 0:00:03
#    ------------------------------------- -- 7.6/8.2 MB 289.4 kB/s eta 0:00:03
#    ------------------------------------- -- 7.6/8.2 MB 289.4 kB/s eta 0:00:03
#    -------------------------------------- - 7.9/8.2 MB 292.2 kB/s eta 0:00:02
#    -------------------------------------- - 7.9/8.2 MB 292.2 kB/s eta 0:00:02
#    -------------------------------------- - 7.9/8.2 MB 292.2 kB/s eta 0:00:02
#    ---------------------------------------  8.1/8.2 MB 294.9 kB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 295.4 kB/s  0:00:27
# Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp311-cp311-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.4 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.4 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.4 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.4 MB 399.6 kB/s eta 0:00:05
#    -------- ------------------------------- 0.5/2.4 MB 399.6 kB/s eta 0:00:05
#    -------- ------------------------------- 0.5/2.4 MB 399.6 kB/s eta 0:00:05
#    ------------- -------------------------- 0.8/2.4 MB 385.8 kB/s eta 0:00:05
#    ------------- -------------------------- 0.8/2.4 MB 385.8 kB/s eta 0:00:05
#    ------------- -------------------------- 0.8/2.4 MB 385.8 kB/s eta 0:00:05
#    ----------------- ---------------------- 1.0/2.4 MB 390.3 kB/s eta 0:00:04
#    ----------------- ---------------------- 1.0/2.4 MB 390.3 kB/s eta 0:00:04
#    ----------------- ---------------------- 1.0/2.4 MB 390.3 kB/s eta 0:00:04
#    ---------------------- ----------------- 1.3/2.4 MB 399.5 kB/s eta 0:00:03
#    ---------------------- ----------------- 1.3/2.4 MB 399.5 kB/s eta 0:00:03
#    -------------------------- ------------- 1.6/2.4 MB 411.3 kB/s eta 0:00:02
#    -------------------------- ------------- 1.6/2.4 MB 411.3 kB/s eta 0:00:02
#    -------------------------- ------------- 1.6/2.4 MB 411.3 kB/s eta 0:00:02
#    ------------------------------- -------- 1.8/2.4 MB 414.2 kB/s eta 0:00:02
#    ------------------------------- -------- 1.8/2.4 MB 414.2 kB/s eta 0:00:02
#    ------------------------------- -------- 1.8/2.4 MB 414.2 kB/s eta 0:00:02
#    ----------------------------------- ---- 2.1/2.4 MB 418.0 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.4 MB 418.0 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.4 MB 418.0 kB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 414.9 kB/s  0:00:05
# Downloading kiwisolver-1.5.0-cp311-cp311-win_amd64.whl (73 kB)
# Downloading pillow-12.2.0-cp311-cp311-win_amd64.whl (7.1 MB)
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.1 MB 441.3 kB/s eta 0:00:15
#    -- ------------------------------------- 0.5/7.1 MB 441.3 kB/s eta 0:00:15
#    -- ------------------------------------- 0.5/7.1 MB 441.3 kB/s eta 0:00:15
#    ---- ----------------------------------- 0.8/7.1 MB 424.5 kB/s eta 0:00:15
#    ---- ----------------------------------- 0.8/7.1 MB 424.5 kB/s eta 0:00:15
#    ----- ---------------------------------- 1.0/7.1 MB 426.5 kB/s eta 0:00:15
#    ----- ---------------------------------- 1.0/7.1 MB 426.5 kB/s eta 0:00:15
#    ----- ---------------------------------- 1.0/7.1 MB 426.5 kB/s eta 0:00:15
#    ----- ---------------------------------- 1.0/7.1 MB 426.5 kB/s eta 0:00:15
#    ------- -------------------------------- 1.3/7.1 MB 409.1 kB/s eta 0:00:15
#    ------- -------------------------------- 1.3/7.1 MB 409.1 kB/s eta 0:00:15
#    ------- -------------------------------- 1.3/7.1 MB 409.1 kB/s eta 0:00:15
#    -------- ------------------------------- 1.6/7.1 MB 401.3 kB/s eta 0:00:14
#    -------- ------------------------------- 1.6/7.1 MB 401.3 kB/s eta 0:00:14
#    -------- ------------------------------- 1.6/7.1 MB 401.3 kB/s eta 0:00:14
#    ---------- ----------------------------- 1.8/7.1 MB 404.2 kB/s eta 0:00:13
#    ---------- ----------------------------- 1.8/7.1 MB 404.2 kB/s eta 0:00:13
#    ----------- ---------------------------- 2.1/7.1 MB 412.1 kB/s eta 0:00:13
#    ----------- ---------------------------- 2.1/7.1 MB 412.1 kB/s eta 0:00:13
#    ----------- ---------------------------- 2.1/7.1 MB 412.1 kB/s eta 0:00:13
#    ------------- -------------------------- 2.4/7.1 MB 418.1 kB/s eta 0:00:12
#    ------------- -------------------------- 2.4/7.1 MB 418.1 kB/s eta 0:00:12
#    ------------- -------------------------- 2.4/7.1 MB 418.1 kB/s eta 0:00:12
#    -------------- ------------------------- 2.6/7.1 MB 420.6 kB/s eta 0:00:11
#    -------------- ------------------------- 2.6/7.1 MB 420.6 kB/s eta 0:00:11
#    ---------------- ----------------------- 2.9/7.1 MB 425.8 kB/s eta 0:00:10
#    ---------------- ----------------------- 2.9/7.1 MB 425.8 kB/s eta 0:00:10
#    ---------------- ----------------------- 2.9/7.1 MB 425.8 kB/s eta 0:00:10
#    ----------------- ---------------------- 3.1/7.1 MB 428.1 kB/s eta 0:00:10
#    ----------------- ---------------------- 3.1/7.1 MB 428.1 kB/s eta 0:00:10
#    ------------------- -------------------- 3.4/7.1 MB 431.1 kB/s eta 0:00:09
#    ------------------- -------------------- 3.4/7.1 MB 431.1 kB/s eta 0:00:09
#    ------------------- -------------------- 3.4/7.1 MB 431.1 kB/s eta 0:00:09
#    -------------------- ------------------- 3.7/7.1 MB 431.9 kB/s eta 0:00:08
#    -------------------- ------------------- 3.7/7.1 MB 431.9 kB/s eta 0:00:08
#    -------------------- ------------------- 3.7/7.1 MB 431.9 kB/s eta 0:00:08
#    ---------------------- ----------------- 3.9/7.1 MB 433.3 kB/s eta 0:00:08
#    ---------------------- ----------------- 3.9/7.1 MB 433.3 kB/s eta 0:00:08
#    ----------------------- ---------------- 4.2/7.1 MB 439.2 kB/s eta 0:00:07
#    ----------------------- ---------------- 4.2/7.1 MB 439.2 kB/s eta 0:00:07
#    ------------------------- -------------- 4.5/7.1 MB 445.9 kB/s eta 0:00:06
#    ------------------------- -------------- 4.5/7.1 MB 445.9 kB/s eta 0:00:06
#    -------------------------- ------------- 4.7/7.1 MB 448.4 kB/s eta 0:00:06
#    -------------------------- ------------- 4.7/7.1 MB 448.4 kB/s eta 0:00:06
#    ---------------------------- ----------- 5.0/7.1 MB 456.9 kB/s eta 0:00:05
#    ---------------------------- ----------- 5.0/7.1 MB 456.9 kB/s eta 0:00:05
#    ----------------------------- ---------- 5.2/7.1 MB 466.7 kB/s eta 0:00:04
#    ------------------------------- -------- 5.5/7.1 MB 475.9 kB/s eta 0:00:04
#    ------------------------------- -------- 5.5/7.1 MB 475.9 kB/s eta 0:00:04
#    -------------------------------- ------- 5.8/7.1 MB 487.9 kB/s eta 0:00:03
#    ---------------------------------- ----- 6.0/7.1 MB 499.5 kB/s eta 0:00:03
#    ----------------------------------- ---- 6.3/7.1 MB 509.7 kB/s eta 0:00:02
#    ------------------------------------- -- 6.6/7.1 MB 521.5 kB/s eta 0:00:02
#    -------------------------------------- - 6.8/7.1 MB 533.6 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.1 MB 545.9 kB/s eta 0:00:01
#    ---------------------------------------- 7.1/7.1 MB 541.6 kB/s  0:00:13
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
#
#    ---------------------------------------- 0/8 [pyparsing]
#    ---------------------------------------- 0/8 [pyparsing]
#    ---------------------------------------- 0/8 [pyparsing]
#    ---------------------------------------- 0/8 [pyparsing]
#    ---------------------------------------- 0/8 [pyparsing]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ---------------------------------------- 8/8 [seaborn]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.10.9 pillow-12.2.0 pyparsing-3.3.2 seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\LapOne MX\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in C:\Users\LapOne MX\AppData\Roaming\Python\Python311\site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\LapOne MX\AppData\Roaming\Python\Python311\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\LapOne MX\AppData\Roaming\Python\Python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\LapOne MX\AppData\Roaming\Python\Python311\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\LapOne MX\AppData\Roaming\Python\Python311\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in C:\Users\LapOne MX\AppData\Roaming\Python\Python311\site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in C:\Users\val\anaconda\envs\Extraccion9AVS\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\LapOne MX\AppData\Roaming\Python\Python311\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\LapOne MX\AppData\Roaming\Python\Python311\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\val\anaconda\envs\Extraccion9AVS\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\val\anaconda\envs\Extraccion9AVS\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Graficamos como se generaron las edades
plt.figure(figsize = (8,4))
sns.histplot(dfInfluencer["edad"], bins=10)
plt.title("Distribucion de edades")
plt.show()

# %%
# Graficamos la cnatidad de usuarios por plataforma
plt.figure(figsize=(8,4))
sns.countplot(x="plataforma", data = dfInfluencer)
plt.title("Cantidad de usuarios por plataforma")
plt.show()
